# %%
import csv
import numpy as np
from sqlalchemy import create_engine
import psycopg2
import tushare as ts
import pandas as pd
from time import sleep

ts.set_token('cfd0f555b15a532de3dcfb0b910661ca48edca2b5571833144d999df')
pro = ts.pro_api()
engine = create_engine('postgresql+psycopg2://postgres:bcd-199c@localhost:5432/postgres')

def get_code(start='20170101'):
    df = pro.stock_basic(list_status='L')
    codes = df.loc[df.list_date<start]
    return codes['ts_code'].values


# 股票日线
def get_bar(code,start='20170101',end='20220210'):
    df=ts.pro_bar(ts_code=code, adj='hfq', start_date=start, end_date=end)
    return df


def insert_sql(data,db_name,if_exists='append'):
    try:
#        data.to_sql(db_name,engine,index=True,index_label=['ts_code','trade_date'],if_exists='append')
        data.to_sql(db_name,engine,index=False,if_exists='append')
        print('insert success')
    except:
        pass


# 数据库查询
def get_bar_sql(ts_code):
    df=pd.read_sql("select * from stock_data where ts_code='"+ ts_code + "'" , engine)
    df=df[['trade_date', 'open', 'high', 'low', 'close', 'pre_close', 'change', 'pct_chg', 'vol', 'amount']]
    return np.array(df)


def update_sql(start,end,db_name):
#    from datetime import datetime,timedelta
    for code in get_code():
        try:
            data=get_bar(code,start,end)
            insert_sql(data,db_name)
        except:
            print(code+" failed.")
            pass
    print(f'{start}:{end}期间数据已成功更新')
    

# df = pro.adj_factor(ts_code='000001.SZ', trade_date='')

# %%
update_sql('20180211','20220218','stock_data')
# Out:
# "None of [Index(['trade_date', 'adj_factor'], dtype='object')] are in the [columns]"
# insert success
# insert success
# "None of [Index(['trade_date', 'adj_factor'], dtype='object')] are in the [columns]"
# HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=30)
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0a00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0760>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600697.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0be0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0c70>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0b50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600698.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0640>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0730>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c08e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600699.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0c70>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0910>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0a00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600702.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c08e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c08e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c08e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600703.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c01f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c01f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c01f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600704.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0340>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0eb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0eb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600705.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c04c0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0a90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0a90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600706.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c03d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0cd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0cd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600707.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c00a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c00a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c00a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600708.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c06a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c06a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c06a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600710.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c01f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c01f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c01f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600711.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0b50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0b50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0b50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600712.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0bb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0bb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c02e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600713.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0280>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0280>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0280>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600714.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c09d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c09d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c09d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600715.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0340>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0340>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0370>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600716.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0b50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0b50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0b50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600717.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0a00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0a00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0a00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600718.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0760>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0760>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0760>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600719.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0ac0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0ac0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0ac0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600720.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c02b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c02b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c02e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600721.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c00a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c00a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c00a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600722.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c06a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c06a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c06a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600724.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0340>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0340>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0190>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600725.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c05b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c05b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c05b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600726.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c09d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0ac0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0ac0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600727.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0280>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0280>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0280>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600728.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0190>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0070>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0ac0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600729.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c03d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c03d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c03d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600730.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0550>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0550>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c04c0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600731.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddf8b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c01f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0190>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600732.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0ac0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0d90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c04c0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600733.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0610>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0490>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0e50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600734.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0fa0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0d90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0070>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600735.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0070>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c03a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0220>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600736.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0cd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0730>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0a90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600737.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c05b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0bb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0220>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600738.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0220>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0220>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c03a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600739.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0610>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c01f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c00a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600740.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0a60>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0e50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0550>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600741.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0550>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0760>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0c40>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600742.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0c40>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c00d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0670>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600743.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0be0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0a00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c06d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600744.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c02b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0490>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0c40>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600745.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0550>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c08e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c09d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600746.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c09d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c09d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0d90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600748.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0b50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0a60>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0730>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600749.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c00d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0340>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0e50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600750.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0490>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0910>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0eb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600751.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c08e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0190>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0640>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600753.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c03a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0280>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0070>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600754.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0070>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0ac0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0bb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600755.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0bb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c08e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0370>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600756.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0b80>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0910>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0280>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600757.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0280>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c00d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0a30>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600758.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0a30>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c08e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0070>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 600759.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c06a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f8c0220>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# ...
# 603928.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e040>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88ebe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddf760>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603929.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88ee80>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88ea30>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddf610>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603936.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e280>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddfd90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88ebe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603939.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e9a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e0d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddf610>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603958.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88ee80>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e280>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddfdf0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603959.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88ebe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e760>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddf220>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603968.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e100>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e9a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddf610>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603969.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88ea00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddf280>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88eb20>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603977.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88ea60>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88efd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddf610>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603979.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e1f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88ea60>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddf2b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603986.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e100>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e370>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddf8e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603987.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e040>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88eac0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddfc70>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603988.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e0d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88eeb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddf220>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603989.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e9a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddf280>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88ea60>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603990.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88ebe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e0d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e280>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603993.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddf8e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e280>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddfdf0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603996.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88eac0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddf850>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88edf0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603997.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e1f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e190>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e760>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603998.SH failed.
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddf850>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12f88e1f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12fddffd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 603999.SH failed.
# 20220211:20220218期间数据已成功更新

# %%
df = get_bar('000001.SZ',start='20220211',end='20220217')

insert_sql(df,'stock_data')

# %%
# 沪深300   
df = pro.index_daily(ts_code='399300.SZ')
insert_sql(df,'stock_data')
